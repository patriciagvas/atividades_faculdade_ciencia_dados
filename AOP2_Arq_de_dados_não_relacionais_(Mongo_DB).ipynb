# %% [markdown]
# **Alunas:** Alessandra Izo (202526273), Patrícia Garcia Vasconselos (202526109)

# %% [markdown]
# Orientações:
#
# Nesta atividade você deverá criar um banco de dados não relacional no MongoDB de uma Universidade para tratar dos alunos, disciplinas e professores.
#
# 1. Criar o banco de dados "universidade".
# 2. Criar a collection "alunos":
# – nome
# – matrícula
# – email
# – curso
# – cep
# – disciplinas: [ {nome, nota1, nota2, mediaFinal, nome_do_professor} , {...} ]
# 3. Cadastrar alunos: inserir o primeiro dado com insertOne e os demais dados com insertMany.
# 4. Criar a collection "professores":
# – nome
# – matricula
# – formação
# – carga horária
# – disciplinas : [nome1, ... ]
# 5. Cadastrar professores: inserir o primeiro dado com insertOne e os demais dados com insertMany.
# 6. Pesquisar na collection de professores, aqueles cuja carga horária é maior que 30 e menor que 40.
# 7. Atualizar a formação de um professor específico.
# 8. Remover todos os alunos de Vila Velha (com cep entre 29100001 e 29129999).

# %%
# %pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 10.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# 1. Criar o banco de dados "universidade".
# 2. Criar a collection "alunos"

# %%
import pymongo

cliente = pymongo.MongoClient("mongodb+srv://pvasconselosg_db_user:fDXaOdjJAUlpeWMi@clusteruvv.s7l8gnj.mongodb.net/?appName=ClusterUVV")
db = cliente['universidade'] #database
collection = db['alunos'] #collection para os dados dos alunos

# %% [markdown]
# 3. Cadastrar alunos: inserir o primeiro dado com insertOne e os demais dados com insertMany.

# %%
# inserir o primeiro dado
primeiro_dado = {
    "nome": "Ana Luiza Costa",
    "matricula": "20240001",
    "email": "ana.luiza@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29101001",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 9.0,
        "nota2": 8.5,
        "mediaFinal": 8.75,
        "nome_do_professor": "Dr. João Costa"
      },
      {
        "nome": "Estrutura de Dados",
        "nota1": 7.5,
        "nota2": 8.0,
        "mediaFinal": 7.75,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  }
collection.insert_one(primeiro_dado)
# Out:
# InsertOneResult(ObjectId('69106f0295bec65588c038b7'), acknowledged=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dados_alunos = [
  {
    "nome": "Bruno Henrique Santos",
    "matricula": "20240002",
    "email": "bruno.santos@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29102999",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 6.0,
        "nota2": 7.5,
        "mediaFinal": 6.75,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Carla Roberta Oliveira",
    "matricula": "20240003",
    "email": "carla.oliveira@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29090000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 8.0,
        "nota2": 9.0,
        "mediaFinal": 8.5,
        "nome_do_professor": "Dr. Pedro Alves"
      },
      {
        "nome": "Segurança da Informação",
        "nota1": 7.0,
        "nota2": 7.0,
        "mediaFinal": 7.0,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Daniel Mendes Lima",
    "matricula": "20240004",
    "email": "daniel.lima@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29125050",
    "disciplinas": [
      {
        "nome": "Estrutura de Dados",
        "nota1": 9.5,
        "nota2": 9.5,
        "mediaFinal": 9.5,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Eduarda Pereira Cruz",
    "matricula": "20240005",
    "email": "eduarda.cruz@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29160100",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 5.5,
        "nota2": 6.5,
        "mediaFinal": 6.0,
        "nome_do_professor": "Dra. Maria Pereira"
      },
      {
        "nome": "Sistemas Operacionais",
        "nota1": 8.0,
        "nota2": 7.5,
        "mediaFinal": 7.75,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Fernando Souza Aguiar",
    "matricula": "20240006",
    "email": "fernando.aguiar@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29104005",
    "disciplinas": [
      {
        "nome": "Processamento Distribuído",
        "nota1": 8.5,
        "nota2": 8.5,
        "mediaFinal": 8.5,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Gabriela Vitoria Neves",
    "matricula": "20240007",
    "email": "gabriela.neves@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29100500",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 9.0,
        "nota2": 9.5,
        "mediaFinal": 9.25,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Hugo Rafael Batista",
    "matricula": "20240008",
    "email": "hugo.batista@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29140000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 6.5,
        "nota2": 6.0,
        "mediaFinal": 6.25,
        "nome_do_professor": "Dr. Pedro Alves"
      },
      {
        "nome": "Estrutura de Dados",
        "nota1": 5.0,
        "nota2": 6.0,
        "mediaFinal": 5.5,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Isabela Cristina Dias",
    "matricula": "20240009",
    "email": "isabela.dias@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29110010",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 8.5,
        "nota2": 9.0,
        "mediaFinal": 8.75,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Julio Cezar Rocha",
    "matricula": "20240010",
    "email": "julio.rocha@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29129999",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 7.0,
        "nota2": 7.0,
        "mediaFinal": 7.0,
        "nome_do_professor": "Dr. João Costa"
      },
      {
        "nome": "Sistemas Operacionais",
        "nota1": 7.5,
        "nota2": 8.5,
        "mediaFinal": 8.0,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Kellen Patricia Alves",
    "matricula": "20240011",
    "email": "kellen.alves@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29010001",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 8.5,
        "nota2": 8.0,
        "mediaFinal": 8.25,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Lucas Gabriel Ferreira",
    "matricula": "20240012",
    "email": "lucas.ferreira@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29120020",
    "disciplinas": [
      {
        "nome": "Processamento Distribuído",
        "nota1": 6.5,
        "nota2": 7.0,
        "mediaFinal": 6.75,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Mariana Paula Gomes",
    "matricula": "20240013",
    "email": "mariana.gomes@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29100001",
    "disciplinas": [
      {
        "nome": "Segurança da Informação",
        "nota1": 9.0,
        "nota2": 9.0,
        "mediaFinal": 9.0,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Nicolas Victor Silva",
    "matricula": "20240014",
    "email": "nicolas.silva@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29170000",
    "disciplinas": [
      {
        "nome": "Estrutura de Dados",
        "nota1": 7.0,
        "nota2": 7.5,
        "mediaFinal": 7.25,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Olivia Maria Dutra",
    "matricula": "20240015",
    "email": "olivia.dutra@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29106000",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 7.5,
        "nota2": 8.0,
        "mediaFinal": 7.75,
        "nome_do_professor": "Dr. João Costa"
      },
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 6.0,
        "nota2": 7.0,
        "mediaFinal": 6.5,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Pedro Afonso Correia",
    "matricula": "20240016",
    "email": "pedro.correia@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29050000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 7.5,
        "nota2": 7.5,
        "mediaFinal": 7.5,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Quelen Rosa Lima",
    "matricula": "20240017",
    "email": "quelen.lima@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29105550",
    "disciplinas": [
      {
        "nome": "Sistemas Operacionais",
        "nota1": 9.0,
        "nota2": 9.0,
        "mediaFinal": 9.0,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Ricardo Menezes Costa",
    "matricula": "20240018",
    "email": "ricardo.costa@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29126100",
    "disciplinas": [
      {
        "nome": "Estrutura de Dados",
        "nota1": 5.0,
        "nota2": 5.0,
        "mediaFinal": 5.0,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Sofia Emanuelly Barbosa",
    "matricula": "20240019",
    "email": "sofia.barbosa@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29150000",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 6.5,
        "nota2": 7.0,
        "mediaFinal": 6.75,
        "nome_do_professor": "Prof. Ricardo Lima"
      },
      {
        "nome": "Segurança da Informação",
        "nota1": 8.0,
        "nota2": 8.5,
        "mediaFinal": 8.25,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Thiago Alex Moreira",
    "matricula": "20240020",
    "email": "thiago.moreira@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29108000",
    "disciplinas": [
      {
        "nome": "Processamento Distribuído",
        "nota1": 9.5,
        "nota2": 9.0,
        "mediaFinal": 9.25,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Ursula Fernanda Guimarães",
    "matricula": "20240021",
    "email": "ursula.guimaraes@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29129000",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 8.0,
        "nota2": 8.0,
        "mediaFinal": 8.0,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Victor Hugo Pereira",
    "matricula": "20240022",
    "email": "victor.pereira@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29045000",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 7.5,
        "nota2": 8.5,
        "mediaFinal": 8.0,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Wallace Souza Melo",
    "matricula": "20240023",
    "email": "wallace.melo@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29103000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 9.0,
        "nota2": 8.5,
        "mediaFinal": 8.75,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Xenia Rayssa Pires",
    "matricula": "20240024",
    "email": "xenia.pires@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29100050",
    "disciplinas": [
      {
        "nome": "Sistemas Operacionais",
        "nota1": 6.0,
        "nota2": 7.0,
        "mediaFinal": 6.5,
        "nome_do_professor": "Prof. Ricardo Lima"
      },
      {
        "nome": "Processamento Distribuído",
        "nota1": 7.0,
        "nota2": 7.0,
        "mediaFinal": 7.0,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Yago Davi Ribeiro",
    "matricula": "20240025",
    "email": "yago.ribeiro@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29145000",
    "disciplinas": [
      {
        "nome": "Estrutura de Dados",
        "nota1": 8.0,
        "nota2": 8.0,
        "mediaFinal": 8.0,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Zara Bianca Fernandes",
    "matricula": "20240026",
    "email": "zara.fernandes@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29106200",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 7.0,
        "nota2": 8.0,
        "mediaFinal": 7.5,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Aline Ferreira Diniz",
    "matricula": "20240027",
    "email": "aline.diniz@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29060000",
    "disciplinas": [
      {
        "nome": "Segurança da Informação",
        "nota1": 9.5,
        "nota2": 9.5,
        "mediaFinal": 9.5,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Bernardo Lopes Rocha",
    "matricula": "20240028",
    "email": "bernardo.rocha@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29111111",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 5.0,
        "nota2": 6.0,
        "mediaFinal": 5.5,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Cecilia Miranda Nunes",
    "matricula": "20240029",
    "email": "cecilia.nunes@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29122222",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 8.0,
        "nota2": 9.0,
        "mediaFinal": 8.5,
        "nome_do_professor": "Dra. Maria Pereira"
      },
      {
        "nome": "Redes de Computadores",
        "nota1": 7.0,
        "nota2": 8.0,
        "mediaFinal": 7.5,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Diego Emanuel Silveira",
    "matricula": "20240030",
    "email": "diego.silveira@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29173000",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 9.0,
        "nota2": 9.0,
        "mediaFinal": 9.0,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Evelyn Ferreira da Luz",
    "matricula": "20240031",
    "email": "evelyn.luz@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29107777",
    "disciplinas": [
      {
        "nome": "Estrutura de Dados",
        "nota1": 6.5,
        "nota2": 7.0,
        "mediaFinal": 6.75,
        "nome_do_professor": "Dra. Maria Pereira"
      },
      {
        "nome": "Sistemas Operacionais",
        "nota1": 7.5,
        "nota2": 7.5,
        "mediaFinal": 7.5,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Felipe Augusto Borges",
    "matricula": "20240032",
    "email": "felipe.borges@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29124000",
    "disciplinas": [
      {
        "nome": "Processamento Distribuído",
        "nota1": 8.0,
        "nota2": 8.0,
        "mediaFinal": 8.0,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Giovanna Ramos Freire",
    "matricula": "20240033",
    "email": "giovanna.freire@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29080000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 5.5,
        "nota2": 6.5,
        "mediaFinal": 6.0,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Henrique Xavier Pimentel",
    "matricula": "20240034",
    "email": "henrique.pimentel@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29102010",
    "disciplinas": [
      {
        "nome": "Segurança da Informação",
        "nota1": 7.5,
        "nota2": 8.5,
        "mediaFinal": 8.0,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Ingrid Santos Correia",
    "matricula": "20240035",
    "email": "ingrid.correia@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29165000",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 9.0,
        "nota2": 9.5,
        "mediaFinal": 9.25,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "João Pedro Almeida",
    "matricula": "20240036",
    "email": "joao.almeida@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29112000",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 7.0,
        "nota2": 7.0,
        "mediaFinal": 7.0,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Larissa Gomes Mendes",
    "matricula": "20240037",
    "email": "larissa.mendes@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29129001",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 8.0,
        "nota2": 8.0,
        "mediaFinal": 8.0,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Marcelo Vinicius Dutra",
    "matricula": "20240038",
    "email": "marcelo.dutra@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29030000",
    "disciplinas": [
      {
        "nome": "Sistemas Operacionais",
        "nota1": 6.0,
        "nota2": 6.0,
        "mediaFinal": 6.0,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Natasha Hellen Teixeira",
    "matricula": "20240039",
    "email": "natasha.teixeira@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29109000",
    "disciplinas": [
      {
        "nome": "Estrutura de Dados",
        "nota1": 8.5,
        "nota2": 8.5,
        "mediaFinal": 8.5,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Otávio Augusto Morais",
    "matricula": "20240040",
    "email": "otavio.morais@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29115000",
    "disciplinas": [
      {
        "nome": "Processamento Distribuído",
        "nota1": 7.5,
        "nota2": 8.0,
        "mediaFinal": 7.75,
        "nome_do_professor": "Dr. João Costa"
      },
      {
        "nome": "Segurança da Informação",
        "nota1": 6.0,
        "nota2": 6.5,
        "mediaFinal": 6.25,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Pamela Roberta Castro",
    "matricula": "20240041",
    "email": "pamela.castro@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29120000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 8.5,
        "nota2": 9.0,
        "mediaFinal": 8.75,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Quirino da Silva",
    "matricula": "20240042",
    "email": "quirino.silva@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29070000",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 6.0,
        "nota2": 7.0,
        "mediaFinal": 6.5,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Renata Cristina Viana",
    "matricula": "20240043",
    "email": "renata.viana@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29101005",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 5.0,
        "nota2": 5.0,
        "mediaFinal": 5.0,
        "nome_do_professor": "Dra. Maria Pereira"
      },
      {
        "nome": "Sistemas Operacionais",
        "nota1": 8.5,
        "nota2": 8.5,
        "mediaFinal": 8.5,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Sérgio Luiz Nogueira",
    "matricula": "20240044",
    "email": "sergio.nogueira@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29107000",
    "disciplinas": [
      {
        "nome": "Cloud Computing",
        "nota1": 7.5,
        "nota2": 7.5,
        "mediaFinal": 7.5,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  },
  {
    "nome": "Tatiane Ellen Farias",
    "matricula": "20240045",
    "email": "tatiane.farias@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29128000",
    "disciplinas": [
      {
        "nome": "Processamento Distribuído",
        "nota1": 9.0,
        "nota2": 9.0,
        "mediaFinal": 9.0,
        "nome_do_professor": "Dr. João Costa"
      },
      {
        "nome": "Estrutura de Dados",
        "nota1": 7.0,
        "nota2": 7.5,
        "mediaFinal": 7.25,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Ubiratan Costa Pires",
    "matricula": "20240046",
    "email": "ubiratan.pires@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29020000",
    "disciplinas": [
      {
        "nome": "Redes de Computadores",
        "nota1": 8.0,
        "nota2": 8.0,
        "mediaFinal": 8.0,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Viviane Dias Souza",
    "matricula": "20240047",
    "email": "viviane.souza@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29100100",
    "disciplinas": [
      {
        "nome": "Segurança da Informação",
        "nota1": 9.0,
        "nota2": 9.0,
        "mediaFinal": 9.0,
        "nome_do_professor": "Dr. Pedro Alves"
      }
    ]
  },
  {
    "nome": "Wesley Andrade Fontes",
    "matricula": "20240048",
    "email": "wesley.fontes@universidade.edu.br",
    "curso": "Engenharia de Software",
    "cep": "29117000",
    "disciplinas": [
      {
        "nome": "Programação Orientada a Objetos",
        "nota1": 6.5,
        "nota2": 6.5,
        "mediaFinal": 6.5,
        "nome_do_professor": "Dra. Maria Pereira"
      }
    ]
  },
  {
    "nome": "Yasmin Gomes Lacerda",
    "matricula": "20240049",
    "email": "yasmin.lacerda@universidade.edu.br",
    "curso": "Sistemas de Informação",
    "cep": "29104050",
    "disciplinas": [
      {
        "nome": "Banco de Dados NoSQL",
        "nota1": 7.0,
        "nota2": 7.5,
        "mediaFinal": 7.25,
        "nome_do_professor": "Dr. João Costa"
      }
    ]
  },
  {
    "nome": "Zeno Henrique Ramos",
    "matricula": "20240050",
    "email": "zeno.ramos@universidade.edu.br",
    "curso": "Ciência da Computação",
    "cep": "29129500",
    "disciplinas": [
      {
        "nome": "Sistemas Operacionais",
        "nota1": 9.5,
        "nota2": 9.5,
        "mediaFinal": 9.5,
        "nome_do_professor": "Prof. Ricardo Lima"
      }
    ]
  }
]

# %%
# inserir os demais dados dos alunos
collection.insert_many(dados_alunos)
# Out:
# InsertManyResult([ObjectId('69106f1595bec65588c038b8'), ObjectId('69106f1595bec65588c038b9'), ObjectId('69106f1595bec65588c038ba'), ObjectId('69106f1595bec65588c038bb'), ObjectId('69106f1595bec65588c038bc'), ObjectId('69106f1595bec65588c038bd'), ObjectId('69106f1595bec65588c038be'), ObjectId('69106f1595bec65588c038bf'), ObjectId('69106f1595bec65588c038c0'), ObjectId('69106f1595bec65588c038c1'), ObjectId('69106f1595bec65588c038c2'), ObjectId('69106f1595bec65588c038c3'), ObjectId('69106f1595bec65588c038c4'), ObjectId('69106f1595bec65588c038c5'), ObjectId('69106f1595bec65588c038c6'), ObjectId('69106f1595bec65588c038c7'), ObjectId('69106f1595bec65588c038c8'), ObjectId('69106f1595bec65588c038c9'), ObjectId('69106f1595bec65588c038ca'), ObjectId('69106f1595bec65588c038cb'), ObjectId('69106f1595bec65588c038cc'), ObjectId('69106f1595bec65588c038cd'), ObjectId('69106f1595bec65588c038ce'), ObjectId('69106f1595bec65588c038cf'), ObjectId('69106f1595bec65588c038d0'), ObjectId('69106f1595bec65588c0
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Criar a collection "professores":
# – nome
# – matricula
# – formação
# – carga horária
# – disciplinas : [nome1, ... ]

# %%
collection_professores = db['professores']

# %% [markdown]
# 5. Cadastrar professores: inserir o primeiro dado com insertOne e os demais dados com insertMany.

# %%
# 15 dados fictícios
dados_professores = [
    {
        "nome": "Dra. Juliana Mendes",
        "matricula": "P202502",
        "formacao": "Doutorado em Engenharia Civil",
        "carga_horaria": 35,
        "disciplinas": ["Cálculo Estrutural Avançado", "Gerenciamento de Obras"]
    },
    {
        "nome": "Msc. Ricardo Teixeira",
        "matricula": "P202503",
        "formacao": "Mestrado em Arquitetura",
        "carga_horaria": 20,
        "disciplinas": ["Desenho Arquitetônico", "Teoria e História da Arte"]
    },
    {
        "nome": "Dr. Carlos Santos",
        "matricula": "P202504",
        "formacao": "Doutorado em Física",
        "carga_horaria": 40,
        "disciplinas": ["Física Quântica", "Termodinâmica"]
    },
    {
        "nome": "Dra. Patrícia Oliveira",
        "matricula": "P202505",
        "formacao": "Doutorado em Letras",
        "carga_horaria": 32,
        "disciplinas": ["Língua Portuguesa e Gramática", "Literatura Clássica"]
    },
    {
        "nome": "Msc. Gustavo Pinheiro",
        "matricula": "P202506",
        "formacao": "Mestrado em Economia",
        "carga_horaria": 30,
        "disciplinas": ["Microeconomia", "Finanças Pessoais"]
    },
    {
        "nome": "Dr. Eduardo Costa",
        "matricula": "P202507",
        "formacao": "Doutorado em Biologia",
        "carga_horaria": 40,
        "disciplinas": ["Genética Molecular", "Ecologia"]
    },
    {
        "nome": "Dra. Sofia Ramos",
        "matricula": "P202508",
        "formacao": "Doutorado em História",
        "carga_horaria": 35,
        "disciplinas": ["História Contemporânea", "Culturas Asiáticas"]
    },
    {
        "nome": "Msc. André Viana",
        "matricula": "P202509",
        "formacao": "Mestrado em Química",
        "carga_horaria": 30,
        "disciplinas": ["Química Orgânica", "Análise Instrumental"]
    },
    {
        "nome": "Dr. Mauro Pereira",
        "matricula": "P202510",
        "formacao": "Doutorado em Matemática Aplicada",
        "carga_horaria": 40,
        "disciplinas": ["Cálculo 3", "Álgebra Linear"]
    },
    {
        "nome": "Dra. Lúcia Ferreira",
        "matricula": "P202511",
        "formacao": "Doutorado em Sociologia",
        "carga_horaria": 20,
        "disciplinas": ["Teoria Social", "Pesquisa Qualitativa"]
    },
    {
        "nome": "Msc. Pedro Gomes",
        "matricula": "P202512",
        "formacao": "Mestrado em Marketing Digital",
        "carga_horaria": 30,
        "disciplinas": ["Estratégias de SEO", "Mídia Paga"]
    },
    {
        "nome": "Dr. Alex Souza",
        "matricula": "P202513",
        "formacao": "Doutorado em Direito",
        "carga_horaria": 40,
        "disciplinas": ["Direito Penal", "Direito Constitucional"]
    },
    {
        "nome": "Dra. Isabela Neves",
        "matricula": "P202514",
        "formacao": "Doutorado em Psicologia Clínica",
        "carga_horaria": 20,
        "disciplinas": ["Psicoterapia", "Desenvolvimento Humano"]
    },
    {
        "nome": "Msc. Diego Barros",
        "matricula": "P202515",
        "formacao": "Mestrado em Redes de Computadores",
        "carga_horaria": 30,
        "disciplinas": ["Segurança de Redes", "Cloud Computing"]
    }
]

# %%
primeiro_professor = {
        "nome": "Dr. Fernando Almeida",
        "matricula": "P202501",
        "formacao": "Doutorado em Ciência da Computação",
        "carga_horaria": 40,
        "disciplinas": ["Algoritmos e Estruturas de Dados", "Programação Orientada a Objetos"]
    }

collection_professores.insert_one(primeiro_professor)
# Out:
# InsertOneResult(ObjectId('69106f3b95bec65588c038e9'), acknowledged=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
collection_professores.insert_many(dados_professores)
# Out:
# InsertManyResult([ObjectId('69106f4195bec65588c038ea'), ObjectId('69106f4195bec65588c038eb'), ObjectId('69106f4195bec65588c038ec'), ObjectId('69106f4195bec65588c038ed'), ObjectId('69106f4195bec65588c038ee'), ObjectId('69106f4195bec65588c038ef'), ObjectId('69106f4195bec65588c038f0'), ObjectId('69106f4195bec65588c038f1'), ObjectId('69106f4195bec65588c038f2'), ObjectId('69106f4195bec65588c038f3'), ObjectId('69106f4195bec65588c038f4'), ObjectId('69106f4195bec65588c038f5'), ObjectId('69106f4195bec65588c038f6'), ObjectId('69106f4195bec65588c038f7')], acknowledged=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Pesquisar na collection de professores, aqueles cuja carga horária é maior que 30 e menor que 40.

# %%
for professor in db.professores.find({
    "carga_horaria": {"$gt":30, "$lt":40}
}):
  print(professor)
# Out:
# {'_id': ObjectId('69106f4195bec65588c038ea'), 'nome': 'Dra. Juliana Mendes', 'matricula': 'P202502', 'formacao': 'Doutorado em Engenharia Civil', 'carga_horaria': 35, 'disciplinas': ['Cálculo Estrutural Avançado', 'Gerenciamento de Obras']}
# {'_id': ObjectId('69106f4195bec65588c038ed'), 'nome': 'Dra. Patrícia Oliveira', 'matricula': 'P202505', 'formacao': 'Doutorado em Letras', 'carga_horaria': 32, 'disciplinas': ['Língua Portuguesa e Gramática', 'Literatura Clássica']}
# {'_id': ObjectId('69106f4195bec65588c038f0'), 'nome': 'Dra. Sofia Ramos', 'matricula': 'P202508', 'formacao': 'Doutorado em História', 'carga_horaria': 35, 'disciplinas': ['História Contemporânea', 'Culturas Asiáticas']}

# %% [markdown]
# 7. Atualizar a formação de um professor específico.

# %%
db.professores.update_one(
    {"nome": "Dr. Eduardo Costa"},
    {"$set": {"formacao": "Pós Doutorado em Ciência de Dados"}}
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff000000000000004f'), 'opTime': {'ts': Timestamp(1762684753, 1), 't': 79}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1762684753, 1), 'signature': {'hash': b'\xe1\xb9\x8fL\xc8\x8f\xd05\x02\xecu\xc2{\xf8\xdc\xcfe\xe7\xb4\xde', 'keyId': 7537706044437299203}}, 'operationTime': Timestamp(1762684753, 1), 'updatedExisting': True}, acknowledged=True)

# %%
update_professor = db.professores.find_one({"nome": "Dr. Eduardo Costa"})
print(update_professor)
# Out:
# {'_id': ObjectId('69106f4195bec65588c038ef'), 'nome': 'Dr. Eduardo Costa', 'matricula': 'P202507', 'formacao': 'Pós Doutorado em Ciência de Dados', 'carga_horaria': 40, 'disciplinas': ['Genética Molecular', 'Ecologia']}

# %% [markdown]
# 8. Remover todos os alunos de Vila Velha (com cep entre 29100001 e 29129999).

# %%
collection.delete_many({"cep": { "$gte": "29100001", "$lte": "29129999" }})
# Out:
# DeleteResult({'n': 34, 'electionId': ObjectId('7fffffff000000000000004f'), 'opTime': {'ts': Timestamp(1762684762, 4), 't': 79}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1762684762, 4), 'signature': {'hash': b'\x11\x9a\xc1z\x92(\x0cp\x17@\xdb\xfe\x18\xf4i^\xb0\x11\xeb\xec', 'keyId': 7537706044437299203}}, 'operationTime': Timestamp(1762684762, 4)}, acknowledged=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#fechar a conexão
cliente.close()
